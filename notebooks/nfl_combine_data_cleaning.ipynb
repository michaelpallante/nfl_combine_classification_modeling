# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Read in csv and examine data

# %%
combine = pd.read_csv('../data/nfl_combine_data.csv')

# %%
# Look at descriptive stats
print(combine.shape, '\n')
print(combine.info())
combine.describe().T
# Out:
# (10228, 16)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10228 entries, 0 to 10227
# Data columns (total 16 columns):
# combine_year             10228 non-null int64
# player_name              10228 non-null object
# college                  10228 non-null object
# position                 10228 non-null object
# height_inches            10228 non-null float64
# weight_lbs               10228 non-null int64
# hand_size_inches         8621 non-null float64
# arm_length_inches        8303 non-null float64
# wonderlic_score          431 non-null float64
# 40_yard_dash             9292 non-null float64
# bench_press_reps         6977 non-null float64
# vertitcal_leap_inches    8258 non-null float64
# broad_jump_inches        8107 non-null float64
# 3_cone_drill             4667 non-null float64
# 20_yard_shuttle          7333 non-null float64
# 60_yard_shuttle          3211 non-null float64
# dtypes: float64(11), int64(2), object(3)
# memory usage: 1.2+ MB
# None
#                          count         mean        std     min      25%  \
# combine_year           10228.0  2002.438600  21.930191    5.00  1994.00
# height_inches          10228.0    73.741555   2.638082   64.90    71.90
# weight_lbs             10228.0   240.183125  44.937472  142.00   203.00
# hand_size_inches        8621.0     9.531669   0.627339    7.13     9.13
# arm_length_inches       8303.0    32.223198   1.493612   25.63    31.25
# wonderlic_score          431.0    24.044084   7.614576    4.00    19.00
# 40_yard_dash            9292.0     4.828435   0.309596    4.21     4.59
# bench_press_reps        6977.0    19.822703   6.522123    1.00    15.00
# vertitcal_leap_inches   8258.0    32.022463   4.202037   17.50    29.00
# broad_jump_inches       8107.0   112.403232   9.312732    7.00   106.00
# 3_cone_drill            4667.0     7.340456   0.445726    6.34     7.00
# 20_yard_shuttle         7333.0     4.403492   0.268127    3.73     4.20
# 60_yard_shuttle         3211.0    11.674363   0.425705   10.43    11.38
#
#                             50%      75%      max
# combine_year           2002.000  2012.00  2018.00
# height_inches            74.000    75.75    82.40
# weight_lbs              232.000   275.00   387.00
# hand_size_inches          9.500    10.00    11.88
# arm_length_inches        32.250    33.25    38.50
# wonderlic_score          24.000    29.00    48.00
# 40_yard_dash              4.755     5.04     6.12
# bench_press_reps         20.000    24.00    51.00
# vertitcal_leap_inches    32.000    35.00    46.00
# broad_jump_inches       113.000   119.00   147.00
# 3_cone_drill              7.250     7.62     9.61
# 20_yard_shuttle           4.360     4.57     5.68
# 60_yard_shuttle          11.650    11.93    13.91

# %% [markdown]
# wonderlic, 3_cone_drill, 60_yard_shuttle have many missing values

# %%
combine.head()
# Out:
#    combine_year      player_name          college position  height_inches  \
# 0          2018       Josh Adams       Notre Dame       RB           74.0
# 1          2018      Ola Adeniyi           Toledo       DE           74.0
# 2          2018     Jordan Akins  Central Florida       TE           75.0
# 3          2018  Jaire Alexander       Louisville       CB           71.0
# 4          2018     Austin Allen         Arkansas       QB           72.0
#
#    weight_lbs  hand_size_inches  arm_length_inches  wonderlic_score  \
# 0         213              9.25              33.75              NaN
# 1         248              9.63              31.75              NaN
# 2         249              9.50              32.50              NaN
# 3         192               NaN                NaN              NaN
# 4         210              9.63              30.63              NaN
#
#    40_yard_dash  bench_press_reps  vertitcal_leap_inches  broad_jump_inches  \
# 0           NaN              18.0                    NaN                NaN
# 1          4.83              26.0                   31.5                NaN
# 2           NaN               NaN                    NaN                NaN
# 3          4.38              14.0                   35.0              127.0
# 4          4.81               NaN                   29.5              112.0
#
#    3_cone_drill  20_yard_shuttle  60_yard_shuttle
# 0           NaN              NaN              NaN
# 1          7.21             4.28            12.79
# 2           NaN              NaN              NaN
# 3          6.71             3.98              NaN
# 4          7.18             4.48              NaN

# %%
# Check years of data
combine.combine_year.unique()
# Out:
# array([2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008,
#        2007, 2006,    5, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998,
#        1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1987])

# %%
# Check '5' row: google search reveals he was part of 2005 combine
combine.loc[combine.combine_year == 5]
# Out:
# Empty DataFrame
# Columns: [combine_year, player_name, college, position, height_inches, weight_lbs, hand_size_inches, arm_length_inches, wonderlic_score, 40_yard_dash, bench_press_reps, vertitcal_leap_inches, broad_jump_inches, 3_cone_drill, 20_yard_shuttle, 60_yard_shuttle]
# Index: []

# %%
combine.groupby('combine_year').count()
# Out:
#               player_name  college  position  height_inches  weight_lbs  \
# combine_year
# 1987                  267      267       267            267         267
# 1988                  322      322       322            322         322
# 1989                  308      308       308            308         308
# 1990                  324      324       324            324         324
# 1991                  428      428       428            428         428
# 1992                  438      438       438            438         438
# 1993                  338      338       338            338         338
# 1994                  315      315       315            315         315
# 1995                  310      310       310            310         310
# 1996                  296      296       296            296         296
# 1997                  319      319       319            319         319
# 1998                  303      303       303            303         303
# 1999                  377      377       377            377         377
# 2000                  258      258       258            258         258
# 2001                  266      266       266            266         266
# 2002                  270      270       270            270         270
# 2003                  259      259       259            259         259
# 2004                  274      274       274            274         274
# 2005                  285      285       285            285         285
# 2006                  279      279       279            279         279
# 2007                  271      271       271            271         271
# 2008                  267      267       267            267         267
# 2009                  285      285       285            285         285
# 2010                  287      287       287            287         287
# 2011                  302      302       302            302         302
# 2012                  326      326       326            326         326
# 2013                  293      293       293            293         293
# 2014                  304      304       304            304         304
# 2015                  741      741       741            741         741
# 2016                  319      319       319            319         319
# 2017                  319      319       319            319         319
# 2018                  278      278       278            278         278
#
#               hand_size_inches  arm_length_inches  40_yard_dash  \
# combine_year
# 1987                       237                237           237
# 1988                       316                  1           272
# 1989                         0                  0           270
# 1990                       314                314           287
# 1991                       426                426           371
# 1992                       421                421           364
# 1993                       337                337           270
# 1994                       315                315           249
# 1995                       309                309           218
# 1996                       296                296           222
# 1997                       319                319           245
# 1998                       302                302           225
# 1999                       274                274           377
# 2000                       231                231           258
# 2001                       237                237           266
# 2002                       242                242           270
# 2003                       238                238           259
# 2004                       248                248           274
# 2005                       264                264           285
# 2006                       276                276           279
# 2007                       264                264           271
# 2008                       262                262           267
# 2009                        24                  4           285
# 2010                       151                155           287
# 2011                       302                302           302
# 2012                       307                315           326
# 2013                       282                288           293
# 2014                       287                287           297
# 2015                       313                312           736
# 2016                       304                304           267
# 2017                       302                302           244
# 2018                       221                221           219
#
#               bench_press_reps  vertitcal_leap_inches  broad_jump_inches  \
# combine_year
# 1987                       215                    237                233
# 1988                       277                    264                260
# 1989                       208                    258                255
# 1990                       207                    277                279
# 1991                       297                    369                369
# 1992                       288                    366                358
# 1993                       223                    267                261
# 1994                       181                    245                246
# 1995                       179                    212                205
# 1996                       164                    226                218
# 1997                       201                    247                233
# 1998                       189                    238                234
# 1999                       263                    359                356
# 2000                       174                    224                231
# 2001                       179                    230                206
# 2002                       201                    241                237
# 2003                       181                    222                220
# 2004                       191                    233                235
# 2005                       205                    247                235
# 2006                       202                    263                264
# 2007                       204                    242                236
# 2008                       204                    249                246
# 2009                       237                    249                246
# 2010                       239                    248                234
# 2011                       250                    272                266
# 2012                       244                    267                256
# 2013                       234                    249                257
# 2014                       245                    271                261
# 2015                       224                    256                255
# 2016                       244                    271                266
# 2017                       229                    251                245
# 2018                       198                    208                204
#
#               3_cone_drill  20_yard_shuttle  60_yard_shuttle
# combine_year
# 1987                     0              223              142
# 1988                     0              249              159
# 1989                     0              248              157
# 1990                     0              257              147
# 1991                     0              349              211
# 1992                     0              340              197
# 1993                     0              248              153
# 1994                     0              229              128
# 1995                     0              188              105
# 1996                     0              205              116
# 1997                   216              220              133
# 1998                   216              215              125
# 1999                   336              344              101
# 2000                   200              199              100
# 2001                   179              177               78
# 2002                   193              190               83
# 2003                   188              187               86
# 2004                   194              199               91
# 2005                   219              220               87
# 2006                   226              234              116
# 2007                   213              211               82
# 2008                   206              201               60
# 2009                   217              222               19
# 2010                   205              210               21
# 2011                   248              255              103
# 2012                   220              223               62
# 2013                   203              214               53
# 2014                   222              224               41
# 2015                   225              233               93
# 2016                   206              216               60
# 2017                   186              246               60
# 2018                   149              157               42

# %%
combine.loc[combine.combine_year == 2015].isnull().sum()
# Out:
# combine_year               0
# player_name                0
# college                    0
# position                   0
# height_inches              0
# weight_lbs                 0
# hand_size_inches         428
# arm_length_inches        429
# 40_yard_dash               5
# bench_press_reps         517
# vertitcal_leap_inches    485
# broad_jump_inches        486
# 3_cone_drill             516
# 20_yard_shuttle          508
# 60_yard_shuttle          648
# dtype: int64

# %% [markdown]
# ## Cleaning Functions

# %%
# Clean combine_year record that lists '5' instead of '2005'
def replace_5():
    combine.loc[combine.combine_year == 5, 'combine_year'] = 2005

# Drop 'wonderlic_score' column due to too many missing values
def drop_wonderlic():
    combine.drop('wonderlic_score', axis=1, inplace=True)
    
# Add 'events_missed' columns
def events_missed():
    pass
# Add 'conference' column

# Position standardization

# Regression imputation for missing values

# %%
replace_5()
drop_wonderlic()
